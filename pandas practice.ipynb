# %%
import pandas as pd 
df = pd.read_csv(r"Salary Data (1) - Salary Data (1).csv")
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
# df=pd.read_csv(r'data.txt',sep='/t')
df = pd.read_table(r"data.txt")

df
# Out:
#        sn,name,age,add
# 0   0,ram,44,kathmandu
# 1    1,shayam,77,jhapa
# 2  2,hari,99,bhaktapur

# %%
df = pd.read_json("data.json")
df
# Out:
#      name  age        add
# 0     ram   44  kathmandu
# 1  shayam   77      jhapa
# 2    hari   99  bhaktapur

# %%
for excel to read sheet,
sheet_name="sheetname ,sheet1"

# %%
import pandas as pd 
df = pd.read_csv(r"Salary Data (1) - Salary Data (1).csv")
df
# Out:
#       Age  Gender Education Level                              Job Title  \
# 0    32.0    Male      Bachelor's                      Software Engineer
# 1    28.0  Female        Master's                           Data Analyst
# 2    45.0    Male             PhD                         Senior Manager
# 3    36.0  Female      Bachelor's                        Sales Associate
# 4    52.0    Male        Master's                               Director
# 5    29.0    Male      Bachelor's                      Marketing Analyst
# 6    42.0  Female        Master's                        Product Manager
# 7    31.0    Male      Bachelor's                          Sales Manager
# 8    26.0  Female      Bachelor's                  Marketing Coordinator
# 9    38.0    Male             PhD                       Senior Scientist
# 10   29.0    Male        Master's                     Software Developer
# 11   48.0  Female      Bachelor's                             HR Manager
# ...

# %%
pd.set_option('display.max.rows',375)
pd.set_option('display.max.column',33) 

# to maximize the reading in place of reading first 5 and last 5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
df.shape
# Out:
# (375, 6)

# %%
df.head(10)
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's      Software Engineer                  5.0
# 1  28.0  Female        Master's           Data Analyst                  3.0
# 2  45.0    Male             PhD         Senior Manager                 15.0
# 3  36.0  Female      Bachelor's        Sales Associate                  7.0
# 4  52.0    Male        Master's               Director                 20.0
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0
# 6  120000.0
# 7   80000.0
# ...

# %%
df.tail(10)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 365  43.0    Male        Master's          Director of Marketing
# 366  31.0  Female      Bachelor's       Junior Financial Analyst
# 367  41.0    Male      Bachelor's         Senior Product Manager
# 368  44.0  Female             PhD           Senior Data Engineer
# 369  33.0    Male      Bachelor's        Junior Business Analyst
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 365                 18.0  170000.0
# 366                  3.0   50000.0
# 367                 14.0  150000.0
# 368                 16.0  160000.0
# 369                  4.0   60000.0
# ...

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
# 5        Male
# 6      Female
# 7        Male
# 8      Female
# 9        Male
# 10       Male
# 11     Female
# 12       Male
# 13     Female
# 14       Male
# 15       Male
# 16     Female
# 17       Male
# 18     Female
# 19       Male
# 20     Female
# 21       Male
# 22       Male
# 23     Female
# 24       Male
# 25     Female
# 26     Female
# 27       Male
# 28     Female
# 29       Male
# 30       Male
# 31     Female
# 32       Male
# 33     Female
# 34       Male
# 35       Male
# 36     Female
# 37       Male
# 38     Female
# 39       Male
# 40     Female
# 41       Male
# 42       Male
# 43     Female
# 44       Male
# 45     Female
# 46       Male
# 47     Female
# 48       Male
# 49       Male
# 50     Female
# 51       Male
# 52     Female
# 53       Male
# 54     Female
# 55       Male
# 56     Female
# 57       Male
# 58     Female
# 59       Male
# 60     Female
# 61       Male
# ...

# %%
df.loc[3]
# Out:
# Age                               36.0
# Gender                          Female
# Education Level             Bachelor's
# Job Title              Sales Associate
# Years of Experience                7.0
# Salary                         60000.0
# Name: 3, dtype: object

# %%
df.iloc[88]
# Out:
# Age                                      46.0
# Gender                                   Male
# Education Level                      Master's
# Job Title              Senior Project Manager
# Years of Experience                      21.0
# Salary                               135000.0
# Name: 88, dtype: object

# %%
import pandas as pd 
df = pd.read_csv(r"Salary Data (1) - Salary Data (1).csv")
df
# Out:
#       Age  Gender Education Level                              Job Title  \
# 0    32.0    Male      Bachelor's                      Software Engineer
# 1    28.0  Female        Master's                           Data Analyst
# 2    45.0    Male             PhD                         Senior Manager
# 3    36.0  Female      Bachelor's                        Sales Associate
# 4    52.0    Male        Master's                               Director
# 5    29.0    Male      Bachelor's                      Marketing Analyst
# 6    42.0  Female        Master's                        Product Manager
# 7    31.0    Male      Bachelor's                          Sales Manager
# 8    26.0  Female      Bachelor's                  Marketing Coordinator
# 9    38.0    Male             PhD                       Senior Scientist
# 10   29.0    Male        Master's                     Software Developer
# 11   48.0  Female      Bachelor's                             HR Manager
# ...

# %%
df[df['Years of Experience']>=10]
# Out:
#       Age  Gender Education Level                            Job Title  \
# 2    45.0    Male             PhD                       Senior Manager
# 4    52.0    Male        Master's                             Director
# 6    42.0  Female        Master's                      Product Manager
# 9    38.0    Male             PhD                     Senior Scientist
# 11   48.0  Female      Bachelor's                           HR Manager
# 13   40.0  Female        Master's                      Project Manager
# 15   44.0    Male      Bachelor's                   Operations Manager
# 17   39.0    Male             PhD                      Senior Engineer
# 19   51.0    Male      Bachelor's                       Sales Director
# 21   47.0    Male        Master's                     VP of Operations
# 24   41.0    Male        Master's                    Financial Manager
# 26   37.0  Female        Master's                     Software Manager
# ...

# %%
specific_EducationLevel=['PhD']
df=df[df['Education Level'].isin(specific_EducationLevel)]

# specific_JobTitle=['Senior Scientist']
# df[df['Job Title'].isin(specific_JobTitle)]

# %%
# df[df['Education Level'].str.contains('PhD')]

# %%
# df[df['Education Level'].str.contains('Female')]
# df[df['Gender'].str.contains('Female', na=False)]
# print(female_df)

# female_df = df[df['Gender'] == 'Female']
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education Level, Job Title, Years of Experience, Salary]
# Index: []

# %%
# female_phd_df = phd_df[phd_df['Gender'] == 'Female']

# print(female_phd_df)

# %%
# fitering out using index
df2=df.set_index('Education Level')
df2
# Out:
#                   Age  Gender                        Job Title  \
# Education Level
# PhD              45.0    Male                   Senior Manager
# PhD              38.0    Male                 Senior Scientist
# PhD              39.0    Male                  Senior Engineer
# PhD              43.0  Female                Senior Consultant
# PhD              46.0    Male                   Senior Manager
# PhD              38.0    Male                 Senior Scientist
# PhD              43.0    Male                  Senior Engineer
# PhD              47.0    Male            Senior Data Scientist
# PhD              45.0    Male                Research Director
# PhD              52.0    Male         Chief Technology Officer
# PhD              36.0    Male              Principal Scientist
# PhD              47.0    Male               Research Scientist
# PhD              44.0    Male               Chief Data Officer
# PhD              48.0    Male               Principal Engineer
# ...

# %%
df2.filter(items=['Job Title','Gender'],axis=1)
# Out:
#                                        Job Title  Gender
# Education Level
# PhD                               Senior Manager    Male
# PhD                             Senior Scientist    Male
# PhD                              Senior Engineer    Male
# PhD                            Senior Consultant  Female
# PhD                               Senior Manager    Male
# PhD                             Senior Scientist    Male
# PhD                              Senior Engineer    Male
# PhD                        Senior Data Scientist    Male
# PhD                            Research Director    Male
# PhD                     Chief Technology Officer    Male
# PhD                          Principal Scientist    Male
# PhD                           Research Scientist    Male
# PhD                           Chief Data Officer    Male
# PhD                           Principal Engineer    Male
# PhD                             Senior Scientist  Female
# ...

# %%
df2['Job Title'].filter(like='Senior')
# Out:
# Series([], Name: Job Title, dtype: object)

# %%
df[df['Gender']=='Male']
# Out:
#       Age Gender Education Level                  Job Title  \
# 2    45.0   Male             PhD             Senior Manager
# 9    38.0   Male             PhD           Senior Scientist
# 17   39.0   Male             PhD            Senior Engineer
# 34   46.0   Male             PhD             Senior Manager
# 48   38.0   Male             PhD           Senior Scientist
# 57   43.0   Male             PhD            Senior Engineer
# 63   47.0   Male             PhD      Senior Data Scientist
# 72   45.0   Male             PhD          Research Director
# 83   52.0   Male             PhD   Chief Technology Officer
# 90   36.0   Male             PhD        Principal Scientist
# 96   47.0   Male             PhD         Research Scientist
# 105  44.0   Male             PhD         Chief Data Officer
# 117  48.0   Male             PhD         Principal Engineer
# 133  47.0   Male             PhD  Senior Research Scientist
# 167  46.0   Male             PhD          Senior Researcher
# ...

# %%
df2.filter(items=['Age'],axis = 1)
# Out:
#                   Age
# Education Level
# PhD              45.0
# PhD              38.0
# PhD              39.0
# PhD              43.0
# PhD              46.0
# PhD              38.0
# PhD              43.0
# PhD              47.0
# PhD              45.0
# PhD              52.0
# PhD              36.0
# PhD              47.0
# PhD              44.0
# PhD              48.0
# PhD              44.0
# PhD              47.0
# PhD              42.0
# PhD              43.0
# PhD              51.0
# PhD              46.0
# PhD              42.0
# PhD              44.0
# PhD              50.0
# PhD              45.0
# PhD              41.0
# PhD              45.0
# PhD              50.0
# PhD              46.0
# PhD              42.0
# PhD              44.0
# PhD              46.0
# PhD              45.0
# PhD              50.0
# PhD              46.0
# PhD              45.0
# PhD              46.0
# PhD              44.0
# PhD              49.0
# PhD              44.0
# ...

# %%
df2.iloc[3]
# Out:
# Age                                 43.0
# Gender                            Female
# Job Title              Senior Consultant
# Years of Experience                 15.0
# Salary                          140000.0
# Name: PhD, dtype: object

# %%
df2.iloc[5]
#searching
# Out:
# Age                                38.0
# Gender                             Male
# Job Title              Senior Scientist
# Years of Experience                11.0
# Salary                         120000.0
# Name: PhD, dtype: object

# %%
import pandas as pd 
df = pd.read_csv(r"Salary Data (1) - Salary Data (1).csv")
df
# Out:
#       Age  Gender Education Level                              Job Title  \
# 0    32.0    Male      Bachelor's                      Software Engineer
# 1    28.0  Female        Master's                           Data Analyst
# 2    45.0    Male             PhD                         Senior Manager
# 3    36.0  Female      Bachelor's                        Sales Associate
# 4    52.0    Male        Master's                               Director
# 5    29.0    Male      Bachelor's                      Marketing Analyst
# 6    42.0  Female        Master's                        Product Manager
# 7    31.0    Male      Bachelor's                          Sales Manager
# 8    26.0  Female      Bachelor's                  Marketing Coordinator
# 9    38.0    Male             PhD                       Senior Scientist
# 10   29.0    Male        Master's                     Software Developer
# 11   48.0  Female      Bachelor's                             HR Manager
# ...

# %%
pd.set_option('display.max.rows',375)
pd.set_option('display.max.column',33)

# %%
df[df['Age']>=25].sort_values(by=['Age','Years of Experience'],ascending=True)
# Out:
#       Age  Gender Education Level                              Job Title  \
# 18   25.0  Female      Bachelor's                       Data Entry Clerk
# 49   25.0    Male      Bachelor's                      Help Desk Analyst
# 82   25.0    Male      Bachelor's                   Sales Representative
# 144  25.0  Female        Master's            Junior Marketing Specialist
# 8    26.0  Female      Bachelor's                  Marketing Coordinator
# 38   26.0  Female      Bachelor's                   Customer Success Rep
# 64   26.0    Male      Bachelor's                      Junior Accountant
# 97   26.0    Male      Bachelor's              Junior Software Developer
# 174  26.0  Female        Master's                  Junior Data Scientist
# 125  26.0    Male      Bachelor's                      Junior Accountant
# 153  26.0    Male      Bachelor's     Junior Customer Support Specialist
# 134  27.0    Male      Bachelor's            Junior Sales Representative
# ...
